# %% [markdown]
# # Conclusion
#
# The final model was a Random Forest model, optimized by RandomizedSearchCV.
#
# This model's most important features were:
# - Age Category
# - General Health
# - Diabetic (Yes)
# - Difficulty Walking (Yes)
# - Difficulty Walking (No)
# - Smoking (Yes)
# - Race (White)
# - Diabetic (No)
# - Stroke (Yes)
# - Stroke (No)
# - Smoking (No)
# - Sex (Male)
# - Sex (Female)
#
# Age Category and General Health are by far the most important features in the model, accounting for .45 total feature importance between them.

# %% [markdown]
# ## Future Steps
